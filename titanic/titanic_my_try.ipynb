# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./train.csv")
data = data.drop(["Cabin", "Ticket", "Embarked"], axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data[['Survived', 'Pclass', 'Age', 'Fare']].corr(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
for train_indices, test_indices in split.split(data, data[["Survived", "Pclass", "Sex"]]):
    strat_train_set = data.loc[train_indices]
    strat_test_set = data.loc[test_indices]

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 179          180         0       3
# 565          566         0       3
# 347          348         1       3
# 502          503         0       3
# 335          336         0       3
# ..           ...       ...     ...
# 600          601         1       2
# 409          410         0       3
# 429          430         1       3
# 462          463         0       1
# 653          654         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 179                                Leonard, Mr. Lionel    male  36.0      0
# 565                               Davies, Mr. Alfred J    male  24.0      2
# 347          Davison, Mrs. Thomas Henry (Mary E Finck)  female   NaN      1
# 502                     O'Sullivan, Miss. Bridget Mary  female   NaN      0
# 335                                 Denkoff, Mr. Mitto    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_select, test_select in split.split(data, data[['Survived']]):
    train_set = data.loc[train_select]
    test_set = data.loc[test_select]
