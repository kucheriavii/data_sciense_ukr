# %% [markdown]
# # Notebooks Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x**2+x+1

# %%
#Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
#plot
plt.xlim(-5,5)
plt.ylim(0,15)
plt.plot(x_1, f(x_1))
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.show()

# %% [markdown]
# # Slope and Derivatives

# %%
def df(x):
    return 2*x+1

# %%
#plot function and derivative side by side
plt.figure(figsize=[15,5])
# 1 Chart: cost function
plt.subplot(1,2,1)

plt.title('Cost function', fontsize=17)
plt.xlim([-3,3])
plt.ylim(0,8)
plt.plot(x_1, f(x_1), color='b', linewidth=3)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

#2 Chart: Derivative
plt.subplot(1,2,2)
plt.title('Slope of the cost function', fontsize=17)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.show()

# %%
#plot function and derivative side by side
plt.figure(figsize=[5,17])
# 1 Chart: cost function
plt.subplot(2,1,1)

plt.title('Cost function', fontsize=17)
plt.xlim([-3,3])
plt.ylim(0,8)
plt.plot(x_1, f(x_1), color='b', linewidth=3)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

#2 Chart: Derivative
plt.subplot(2,1,2)
plt.title('Slope of the cost function', fontsize=17)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()
plt.show()

# %% [markdown]
# ## Python loops & Gradient Descent

# %%
#Python for loop
for counter in range(5):
    print('Hello world')
print('End of loop')
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# End of loop

# %%
#Python while loop
counter = 0
while counter < 5:
    print("Counting ", counter)
    counter = counter + 1
print('Ready or not, here I am')
# Out:
# Counting  0
# Counting  1
# Counting  2
# Counting  3
# Counting  4
# Ready or not, here I am

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(1000):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    
    step_size = abs(new_x-previous_x)
    #print(step_size)
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop ran this many times:', n)
        break
    
print('Local minimum occurs at:', new_x)
print('Slope of df(x) value at tgis point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 40
# Local minimum occurs at: -0.49962781616118024
# Slope of df(x) value at tgis point is: 0.0007443676776395236
# f(x) value or cost at this point is: 0.7500001385208099

# %%
#Superimpose the gradient descent calculations
plt.figure(figsize=[15,5])
# 1 Chart: cost function
plt.subplot(1,3,1)

plt.title('Cost function', fontsize=17)
plt.xlim([-3,3])
plt.ylim(0,8)
plt.plot(x_1, f(x_1), color='b', linewidth=3)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha = 0.8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

#2 Chart: Derivative
plt.subplot(1,3,2)
plt.title('Slope of the cost function', fontsize=17)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.6)

plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.grid()

#3 Chart: Derivative (Close up)
plt.subplot(1,3,3)
plt.title('Gradient Descent (close up)', fontsize=17)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-0.55,-0.2)
plt.ylim(-0.3,0.8)
plt.grid()
plt.show()

# %% [markdown]
# # Example 2 - Multiple Minimum vs Initial Guess & Advanced Functions

# %% [markdown]
# ## $$g(x) = x^4 - 4x^2+5$$

# %%
#make some data
x_2 = np.linspace(-2,2,1000)

def g(x):
    return x**4-4*x**2+5

# %%
def dg(x):
    return 4*x**3 - 8*x

# %%
#plot function and derivative side by side
plt.figure(figsize=[15,5])
# 1 Chart: cost function
plt.subplot(1,2,1)

plt.title('Cost function', fontsize=17)
plt.xlim([-3,3])
plt.ylim(0,7)
plt.plot(x_2, g(x_2), color='b', linewidth=3)

plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

#2 Chart: Derivative
plt.subplot(1,2,2)
plt.title('Slope of the cost function', fontsize=17)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.show()

# %%
# Gradient Descent as a Python Function
def gradient_desent(derivative_func, initial_guess, multiplier=0.02, precision=0.001):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(1000):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x-previous_x)
        #print(step_size)

        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_desent(dg, 0.5, 0.01, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.4090774204884804
# Number of steps: 42

# %%
local_min, list_x, deriv_list = gradient_desent(derivative_func=dg, initial_guess=-0.5)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4122375085019094
# Number of steps: 23

# %%
#callling gradient descent function
local_min, list_x, deriv_list = gradient_desent(derivative_func=dg, initial_guess=0.1)

#plot function and derivative and scatterplot side by side
plt.figure(figsize=[15,5])
# 1 Chart: cost function
plt.subplot(1,2,1)

plt.title('Cost function', fontsize=17)
plt.xlim([-3,3])
plt.ylim(0,7)
plt.plot(x_2, g(x_2), color='b', linewidth=3)
plt.scatter(list_x, g(np.array(list_x)), color="red", s=100, alpha=0.8)

plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

#2 Chart: Derivative
plt.subplot(1,2,2)
plt.title('Slope of the cost function', fontsize=17)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5)
plt.scatter(list_x, deriv_list, color="red", s=100, alpha=0.8)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.grid()
plt.show()
